# %%
print("hello")
# Out:
# hello

# %%
import numpy as np 
import matplotlib.pyplot as plt   
def PlotBarGraphR(Plot_Lables,Plot_Values,xlab,ylab,title):  
    fig = plt.figure(figsize = (10, 5)) 
      
    # creating the bar plot 
 
    plt.bar(Plot_Lables, Plot_Values, color ='Blue',width = 0.4) 
      
    plt.xlabel("Algorithm") 
    plt.ylabel("Outlier Detection") 
    plt.title("Clustering Efficiency on the basis of outlier detection") 
    plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt   
def PlotBarGraphR(Plot_Lables,Plot_Values,xlab,ylab,title):  
    fig = plt.figure(figsize = (10, 5)) 
      
    # creating the bar plot 
 
    plt.bar(Plot_Lables, Plot_Values, color ='Blue',width = 0.4) 
      
    plt.xlabel("Algorithm") 
    plt.ylabel("Outlier Detection") 
    plt.title("Clustering Efficiency on the basis of outlier detection") 
    plt.show()

# %%
def makemap(df,cluster_column):
  m=folium.Map(location=[df.longitude.mean(),df.latitude.mean()],zoom_start=10,tiles='stamen toner')
  for _, row in df.iterrows():
 
      
      cluster_colour = cols[row[cluster_column]]
 
      folium.CircleMarker(
          location= [row.longitude,row.latitude],
          radius=0.5,
          popup= row.crimeActivity,
          color=cluster_colour,
          fill=True,
          fill_color=cluster_colour
      ).add_to(m)
  return m

# %%
import matplotlib
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd
import numpy as np
import geopandas as gpd
from tqdm import tqdm
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.datasets import make_blobs
from sklearn.neighbors import KNeighborsClassifier
from kmodes.kmodes import KModes
from ipywidgets import interactive
 
from collections import defaultdict
import folium
import re
 
 
cols = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4',
        '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', '#e6beff', 
        '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', 
        '#000075', '#808080']*10

# %%
df=pd.read_csv("C:/Users/amarn/OneDrive/Desktop/xmlParser/data.csv")
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
df=pd.read_csv("C:/Users/amarn/OneDrive/Desktop/xmlParser/data.csv")
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
df
# Out:
#       latitude  longitude crimeActivity
# 0    78.430939  17.421263   Eve Teasing
# 1    78.432999  17.413401   Eve Teasing
# 2    78.439865  17.414711   Eve Teasing
# 3    78.476258  17.487420   Eve Teasing
# 4    78.478086  17.481092   Eve Teasing
# ..         ...        ...           ...
# 206  78.525137  17.473510        Murder
# 207  78.518614  17.503963    kidnapping
# 208  78.469175  17.488901    kidnapping
# 209  78.502821  17.474820    kidnapping
# 210  78.464369  17.486609    kidnapping
#
# [211 rows x 3 columns]

# %%
df.duplicated(subset=['latitude','longitude']).values.any()
# Out:
# True

# %%
df.isna().values.any()
# Out:
# False

# %%
import folium
m=folium.Map(location=[df.longitude.mean(),df.latitude.mean()],zoom_start=10,tiles='stamen toner')
for _,row in df.iterrows():
  folium.CircleMarker(location=[row.longitude,row.latitude],radius=0.5,popup=row.crimeActivity,color='#1787FE',fill=True,fill_color='#1787FE').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfed334b99dd457dca459227d7ad9ec7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfed334b99dd457dca459227d7ad9ec7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfed334b99dd457dca459227d7ad9ec7 = L.map(
#                 &quot;map_bfed334b99dd457dca459227d7ad9ec7&quot;,
#                 {
#                     center: [17.40384068578199, 78.47765085118483],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_446c30427f5079afdeabbb4246add066 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bfed334b99dd457dca459227d7ad9ec7);
#
#
#             var circle_marker_dadc966f80b4f5d64a59e8669fdc4747 = L.circleMarker(
#                 [17.4212625, 78.430939],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1787FE&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1787FE&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bfed334b99dd457dca459227d7ad9ec7);
#
#
#         var popup_149c61675a182116961310b62f16d3e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da4bb76bba755d53504619bd06648344 = $(`&lt;div id=&quot;html_da4bb76bba755d53504619bd06648344&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_149c61675a182116961310b62f16d3e5.setContent(html_da4bb76bba755d53504619bd06648344);
#
#
#
#         circle_marker_dadc966f80b4f5d64a59e8669fdc4747.bindPopup(popup_149c61675a182116961310b62f16d3e5)
#         ;
#
#
#
#
#             var circle_marker_46b1f00d328359babe8f4698a3553da7 = L.circleMarker(
#                 [17.4134005, 78.432999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1787FE&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1787FE&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bfed334b99dd457dca459227d7ad9ec7);
#
#
#         var popup_6c3835e0c4973a8d5867698946d53ac2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd5d1a54c6c8c4996f0eea248dc8125b = $(`&lt;div id=&quot;html_fd5d1a54c6c8c4996f0eea248dc8125b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_6c3835e0c4973a8d5867698946d53ac2.setContent(html_fd5d1a54c6c8c4996f0eea248dc8125b);
#
#
#
#         circle_marker_46b1f00d328359babe8f4698a3553da7.bindPopup(popup_6c3835e0c4973a8d5867698946d53ac2)
#         ;
#
#
#
#
#             var circle_marker_6b99a9459e95b5727a50c2f54b48330c = L.circleMarker(
#                 [17.4147109, 78.4398654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1787FE&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1787FE&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bfed334b99dd457dca459227d7ad9ec7);
#
#
#         var popup_52f4efd877f91c83f55e1d148ab67010 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_041abf876fe10838a5aaa9d6abdb5cac = $(`&lt;div id=&quot;html_041abf876fe10838a5aaa9d6abdb5cac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_52f4efd877f91c83f55e1d148ab67010.setContent(html_041abf876fe10838a5aaa9d6abdb5cac);
#
#
#
#         circle_marker_6b99a9459e95b5727a50c2f54b48330c.bindPopup(popup_52f4efd877f91c83f55e1d148ab67010)
#         ;

# %%
df=pd.read_csv("C:/Users/amarn/OneDrive/Desktop/xmlParser/data.csv")
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
from sklearn.datasets import make_blobs
X_blobs,_ = make_blobs(n_samples=1000,centers=10,n_features=3,cluster_std=0.5,random_state=4)

# %%
import matplotlib as plt
plt.pyplot.scatter(X_blobs[:,0],X_blobs[:,1],alpha=0.2)

# %%
from sklearn.cluster import KMeans
model=KMeans(n_clusters=4,random_state=17).fit(X_blobs)
class_predictions=model.predict(X_blobs)
# Out:
# c:\Users\amarn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
class_predictions
# Out:
# array([1, 0, 3, 0, 3, 0, 0, 2, 0, 3, 3, 0, 1, 1, 2, 0, 3, 0, 2, 1, 0, 1,
#        0, 3, 0, 1, 3, 1, 3, 0, 2, 1, 3, 3, 3, 1, 1, 2, 1, 2, 2, 0, 0, 1,
#        1, 0, 0, 0, 3, 2, 0, 0, 3, 1, 1, 1, 1, 0, 0, 3, 0, 3, 2, 1, 0, 0,
#        2, 0, 1, 3, 0, 0, 3, 1, 0, 1, 0, 1, 1, 1, 0, 3, 2, 3, 1, 3, 3, 1,
#        3, 1, 0, 1, 2, 1, 3, 2, 1, 0, 3, 1, 3, 1, 2, 3, 0, 2, 2, 3, 3, 2,
#        1, 0, 1, 3, 1, 1, 1, 3, 0, 2, 3, 3, 1, 3, 1, 2, 3, 0, 1, 1, 0, 1,
#        2, 1, 1, 2, 1, 1, 0, 2, 2, 0, 0, 1, 3, 1, 0, 3, 0, 0, 1, 1, 1, 3,
#        0, 0, 1, 3, 3, 0, 1, 1, 1, 1, 2, 3, 1, 0, 2, 3, 1, 0, 1, 0, 1, 0,
#        3, 0, 0, 1, 2, 2, 2, 0, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 1, 0,
#        1, 1, 2, 3, 1, 0, 0, 3, 0, 0, 3, 3, 1, 0, 2, 3, 3, 3, 1, 2, 1, 2,
#        1, 0, 0, 2, 3, 0, 0, 0, 1, 3, 1, 2, 0, 1, 0, 0, 1, 1, 0, 2, 3, 3,
#        0, 1, 2, 2, 1, 0, 0, 0, 0, 0, 2, 1, 0, 1, 2, 3, 1, 3, 3, 3, 2, 1,
#        3, 2, 3, 3, 2, 2, 2, 2, 1, 2, 1, 2, 0, 3, 3, 2, 0, 3, 0, 0, 2, 2,
#        1, 1, 3, 3, 0, 2, 0, 0, 1, 1, 0, 0, 1, 2, 1, 3, 1, 0, 0, 3, 3, 1,
#        1, 1, 2, 2, 2, 0, 0, 0, 1, 1, 3, 2, 0, 1, 2, 1, 0, 0, 1, 0, 1, 3,
#        0, 2, 2, 0, 0, 1, 1, 0, 2, 1, 0, 1, 1, 0, 0, 3, 1, 1, 0, 1, 0, 2,
#        1, 2, 2, 1, 0, 2, 3, 3, 3, 0, 0, 1, 0, 1, 2, 2, 0, 2, 2, 1, 0, 2,
#        2, 1, 0, 0, 1, 2, 2, 0, 2, 0, 0, 1, 1, 2, 2, 1, 2, 1, 1, 0, 1, 1,
#        2, 2, 2, 1, 1, 0, 0, 2, 1, 0, 1, 0, 0, 1, 0, 1, 0, 0, 1, 0, 0, 0,
#        3, 0, 1, 1, 3, 2, 1, 0, 1, 3, 3, 1, 1, 2, 2, 2, 0, 0, 2, 1, 1, 3,
#        1, 1, 2, 3, 0, 3, 1, 3, 2, 3, 3, 1, 3, 1, 1, 0, 2, 0, 2, 1, 3, 0,
#        2, 0, 0, 1, 0, 0, 2, 0, 1, 1, 1, 2, 2, 0, 1, 2, 3, 1, 1, 0, 1, 1,
#        2, 2, 1, 2, 2, 1, 1, 3, 2, 0, 1, 1, 3, 2, 1, 2, 1, 2, 3, 1, 0, 0,
#        2, 0, 3, 0, 0, 3, 0, 2, 1, 1, 0, 2, 0, 2, 0, 0, 0, 3, 1, 3, 1, 3,
#        1, 3, 1, 1, 1, 0, 0, 0, 3, 3, 0, 1, 0, 1, 3, 0, 1, 1, 0, 3, 1, 0,
#        3, 2, 2, 3, 2, 1, 0, 0, 3, 0, 0, 2, 0, 2, 2, 3, 0, 0, 3, 0, 2, 0,
#        0, 3, 0, 3, 0, 3, 3, 1, 3, 2, 0, 0, 1, 1, 2, 0, 1, 1, 1, 2, 1, 0,
#        2, 2, 1, 2, 1, 0, 1, 3, 0, 1, 0, 3, 2, 1, 0, 1, 2, 3, 1, 0, 2, 2,
#        3, 1, 3, 0, 1, 3, 2, 1, 0, 1, 0, 1, 0, 2, 2, 0, 0, 1, 1, 1, 1, 0,
#        3, 1, 1, 0, 1, 1, 3, 1, 0, 0, 3, 0, 0, 1, 0, 1, 0, 3, 1, 0, 2, 0,
#        3, 1, 2, 2, 1, 3, 1, 0, 3, 0, 0, 1, 3, 0, 2, 2, 3, 0, 0, 3, 1, 3,
#        1, 3, 2, 0, 0, 1, 1, 0, 1, 1, 1, 2, 3, 1, 2, 0, 2, 0, 0, 0, 1, 3,
#        0, 0, 1, 0, 0, 0, 2, 0, 3, 1, 0, 1, 0, 1, 1, 0, 1, 0, 3, 2, 2, 3,
#        2, 2, 3, 1, 1, 0, 0, 1, 3, 3, 0, 3, 0, 0, 3, 1, 3, 0, 3, 2, 2, 1,
#        2, 3, 3, 1, 3, 3, 3, 0, 1, 3, 1, 1, 2, 3, 0, 0, 1, 1, 1, 3, 1, 1,
#        3, 3, 1, 2, 3, 2, 0, 0, 0, 1, 3, 0, 0, 1, 0, 2, 3, 3, 2, 0, 0, 2,
#        0, 0, 2, 2, 0, 0, 1, 2, 3, 3, 2, 2, 1, 3, 2, 1, 1, 0, 3, 1, 0, 3,
#        0, 0, 2, 0, 3, 1, 3, 0, 1, 0, 3, 0, 1, 2, 3, 2, 1, 3, 0, 0, 3, 3,
#        0, 1, 1, 3, 3, 0, 3, 0, 2, 3, 0, 1, 1, 2, 3, 2, 0, 3, 3, 1, 0, 0,
#        0, 1, 0, 1, 1, 3, 1, 0, 0, 3, 1, 2, 1, 2, 3, 1, 1, 2, 0, 1, 0, 3,
#        3, 0, 2, 0, 3, 0, 0, 2, 1, 1, 2, 0, 1, 0, 1, 1, 0, 1, 2, 2, 0, 1,
#        3, 0, 3, 3, 3, 1, 0, 3, 1, 2, 3, 3, 3, 0, 2, 3, 2, 0, 3, 2, 2, 1,
#        1, 1, 2, 0, 0, 3, 0, 1, 0, 2, 0, 0, 3, 1, 1, 1, 1, 2, 1, 0, 2, 1,
#        1, 3, 1, 3, 2, 0, 2, 1, 0, 0, 0, 0, 2, 0, 0, 3, 0, 0, 3, 1, 0, 3,
#        1, 1, 3, 0, 1, 2, 2, 1, 1, 2, 3, 1, 0, 3, 1, 0, 1, 1, 1, 0, 1, 0,
#        2, 0, 1, 2, 2, 2, 3, 2, 2, 0])

# %%
unique_clusters=np.unique(class_predictions)
cols=['#e6194b','#3cb44b','#ffe119','#4363d8']
for unique_cluster in unique_clusters:
  X=X_blobs[class_predictions==unique_cluster]
  plt.pyplot.scatter(X[:,0],X[:,1],alpha=0.2,c=cols[unique_cluster])

# %%
data = defaultdict(dict)
for x in range(1,21):
    model = KMeans(n_clusters=4, random_state=17, 
                   max_iter=x, n_init=1).fit(X_blobs)
    
    data[x]['class_predictions'] = model.predict(X_blobs)
    data[x]['centroids'] = model.cluster_centers_
    data[x]['unique_classes'] = np.unique(class_predictions)

# %%
import matplotlib.pyplot as plt
#function to compute the centroid,clusters at a particular instance of iteration.
def f(x):
    class_predictions = data[x]['class_predictions']
    centroids = data[x]['centroids']
    unique_classes = data[x]['unique_classes']

    for unique_class in unique_classes:
            plt.scatter(X_blobs[class_predictions==unique_class][:,0], 
                        X_blobs[class_predictions==unique_class][:,1], 
                        alpha=0.3, c=cols[unique_class])
    plt.scatter(centroids[:,0], centroids[:,1], s=200, c='#000000', marker='v')
    plt.ylim([-15,15]); plt.xlim([-15,15])
    plt.title('How K-Means Clusters')

interactive_plot = interactive(f, x=(1, 21))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=11, description='x', max=21, min=1), Output(layout=Layout(height='350px'…

# %%
import numpy as np

X=np.array(df[['latitude','longitude']],dtype='float64')
plt.scatter(X[:,0],X[:,1],alpha=0.2,s=20)

# %%
v_kmeans=silhouette_score(X_blobs,class_predictions)

# %%
m=makemap(df,'cluster_kmodes')
v_k_modes=silhouette_score(X, class_predictions)
m.save('kmeans.html')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\amarn\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\amarn\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\amarn\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cluster_kmodes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 m=makemap(df,'cluster_kmodes')
#       2 v_k_modes=silhouette_score(X, class_predictions)
#       3 m.save('kmeans.html')
#
# Cell In[43], line 6, in makemap(df, cluster_column)
#       2 m=folium.Map(location=[df.longitude.mean(),df.latitude.mean()],zoom_start=10,tiles='stamen toner')
#       3 for _, row in df.iterrows():
# ----> 6     cluster_colour = cols[row[cluster_column]]
#       8     folium.CircleMarker(
#       9         location= [row.longitude,row.latitude],
#      10         radius=0.5,
#    (...)
#      14         fill_color=cluster_colour
#      15     ).add_to(m)
#      16 return m
#
# File c:\Users\amarn\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\amarn\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File c:\Users\amarn\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'cluster_kmodes'

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_287162f1ca312c17c593496619825fa5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_287162f1ca312c17c593496619825fa5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_287162f1ca312c17c593496619825fa5 = L.map(
#                 &quot;map_287162f1ca312c17c593496619825fa5&quot;,
#                 {
#                     center: [17.40384068578199, 78.47765085118483],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9f94f17434bde0990b6c4cabc18433d = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_287162f1ca312c17c593496619825fa5);
#
#
#             var circle_marker_b494cdfff5c00c614c2f3d8aa2eecaa1 = L.circleMarker(
#                 [17.4212625, 78.430939],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1787FE&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1787FE&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_287162f1ca312c17c593496619825fa5);
#
#
#         var popup_0d303221a2eed2b4412e5d43f4491363 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aab9c0e86c3bd7c42e2239bb9de8a6b0 = $(`&lt;div id=&quot;html_aab9c0e86c3bd7c42e2239bb9de8a6b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_0d303221a2eed2b4412e5d43f4491363.setContent(html_aab9c0e86c3bd7c42e2239bb9de8a6b0);
#
#
#
#         circle_marker_b494cdfff5c00c614c2f3d8aa2eecaa1.bindPopup(popup_0d303221a2eed2b4412e5d43f4491363)
#         ;
#
#
#
#
#             var circle_marker_dcc7e6efadccd3c9f57bd01b86f17d24 = L.circleMarker(
#                 [17.4134005, 78.432999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1787FE&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1787FE&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_287162f1ca312c17c593496619825fa5);
#
#
#         var popup_46e90bca90747b836882efcb08353f53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab01a8cb2e6172250aa866ad6c7bfcfa = $(`&lt;div id=&quot;html_ab01a8cb2e6172250aa866ad6c7bfcfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_46e90bca90747b836882efcb08353f53.setContent(html_ab01a8cb2e6172250aa866ad6c7bfcfa);
#
#
#
#         circle_marker_dcc7e6efadccd3c9f57bd01b86f17d24.bindPopup(popup_46e90bca90747b836882efcb08353f53)
#         ;
#
#
#
#
#             var circle_marker_c4bd84b506710f4a21b0322125775885 = L.circleMarker(
#                 [17.4147109, 78.4398654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1787FE&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1787FE&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_287162f1ca312c17c593496619825fa5);
#
#
#         var popup_984b8b88714ea9262eb981b9e58684a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e19b6d51ab7eb3408bc1c92961be9445 = $(`&lt;div id=&quot;html_e19b6d51ab7eb3408bc1c92961be9445&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_984b8b88714ea9262eb981b9e58684a8.setContent(html_e19b6d51ab7eb3408bc1c92961be9445);
#
#
#
#         circle_marker_c4bd84b506710f4a21b0322125775885.bindPopup(popup_984b8b88714ea9262eb981b9e58684a8)
#         ;

# %%
import numpy as np
import pandas as pd
 
X = np.array(df[['longitude','latitude']], dtype ='float64')    #Features
df['crimeActivity_Classification_no.'] = pd.factorize(df.crimeActivity)[0] #Factorizing Labels
Y= np.array(df[['crimeActivity_Classification_no.']], dtype = 'int')   #Labels

# %%
#splitting of training and testing data.
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 0,test_size=0.33)

# %%
Accuracy_Supervised_Approach=[]

# %%
from sklearn import svm
clf = svm.SVC(kernel="linear")
clf.fit(X_train,Y_train)
 
 
# accuracy on X_test 
accuracy = clf.score(X_test, Y_test) 
print ('Accuracy  '+str(accuracy)) 
 
Accuracy_Supervised_Approach.append(accuracy) 
# creating a confusion matrix 
clf_predictions = clf.predict(X_test)  
cm = confusion_matrix(Y_test, clf_predictions)
# Out:
# Accuracy  0.5571428571428572
# c:\Users\amarn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn import svm
clf = svm.SVC(kernel="sigmoid")
clf.fit(X_train,Y_train)
 
 
# accuracy on X_test 
accuracy = clf.score(X_test, Y_test) 
print ('Accuracy  '+str(accuracy)) 
  
# creating a confusion matrix 
clf_predictions = clf.predict(X_test)  
cm = confusion_matrix(Y_test, clf_predictions)
# Out:
# Accuracy  0.5571428571428572
# c:\Users\amarn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.tree import DecisionTreeClassifier 
dtree_model = DecisionTreeClassifier(max_depth = 5,min_samples_split=2).fit(X_train, Y_train) 
dtree_predictions = dtree_model.predict(X_test) 
 
#Accuracy on X_test.
accuracy = dtree_model.score(X_test, Y_test)
print ('Accuracy  '+str(accuracy)) 
Accuracy_Supervised_Approach.append(accuracy)
  
# creating a confusion matrix 
cm = confusion_matrix(Y_test, dtree_predictions)
# Out:
# Accuracy  0.7142857142857143

# %%
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB().fit(X_train, Y_train) 
gnb_predictions = gnb.predict(X_test) 
  
# accuracy on X_test 
accuracy = gnb.score(X_test, Y_test) 
print ('Accuracy  '+str(accuracy)) 
Accuracy_Supervised_Approach.append(accuracy)
# creating a confusion matrix 
cm = confusion_matrix(Y_test, gnb_predictions)
# Out:
# Accuracy  0.6857142857142857
# c:\Users\amarn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.cluster import KMeans
K_Means= KMeans (n_clusters=4,random_state=0).fit(X)
class_predictions=K_Means.labels_
df['cluster_kmeans']=class_predictions
# Out:
# c:\Users\amarn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
m=makemap(df,'cluster_kmeans')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c53a707e7a3d5ee614c74cb23482b04c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c53a707e7a3d5ee614c74cb23482b04c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c53a707e7a3d5ee614c74cb23482b04c = L.map(
#                 &quot;map_c53a707e7a3d5ee614c74cb23482b04c&quot;,
#                 {
#                     center: [17.40384068578199, 78.47765085118483],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74690030a79c107170c700e835813658 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c53a707e7a3d5ee614c74cb23482b04c);
#
#
#             var circle_marker_01bd8852f0ac25cc475570c5345768fe = L.circleMarker(
#                 [17.4212625, 78.430939],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffe119&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffe119&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c53a707e7a3d5ee614c74cb23482b04c);
#
#
#         var popup_fcbb408d5dd86c95debddbe93e5bb3be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb6c32d09896485177353406cf578843 = $(`&lt;div id=&quot;html_bb6c32d09896485177353406cf578843&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_fcbb408d5dd86c95debddbe93e5bb3be.setContent(html_bb6c32d09896485177353406cf578843);
#
#
#
#         circle_marker_01bd8852f0ac25cc475570c5345768fe.bindPopup(popup_fcbb408d5dd86c95debddbe93e5bb3be)
#         ;
#
#
#
#
#             var circle_marker_5e8c02a7824c9aa99806b164d5402c33 = L.circleMarker(
#                 [17.4134005, 78.432999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffe119&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffe119&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c53a707e7a3d5ee614c74cb23482b04c);
#
#
#         var popup_0b38a25a51f91105af72533b3e62727f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_886499c216cf0c758c431029545e6d20 = $(`&lt;div id=&quot;html_886499c216cf0c758c431029545e6d20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_0b38a25a51f91105af72533b3e62727f.setContent(html_886499c216cf0c758c431029545e6d20);
#
#
#
#         circle_marker_5e8c02a7824c9aa99806b164d5402c33.bindPopup(popup_0b38a25a51f91105af72533b3e62727f)
#         ;
#
#
#
#
#             var circle_marker_83d846897c61516b0738bb658b3d5520 = L.circleMarker(
#                 [17.4147109, 78.4398654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffe119&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffe119&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c53a707e7a3d5ee614c74cb23482b04c);
#
#
#         var popup_937fa280095b817c0f9750d584d18d1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc7001312059988a12dbe4aeeb4e4818 = $(`&lt;div id=&quot;html_cc7001312059988a12dbe4aeeb4e4818&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_937fa280095b817c0f9750d584d18d1d.setContent(html_cc7001312059988a12dbe4aeeb4e4818);
#
#
#
#         circle_marker_83d846897c61516b0738bb658b3d5520.bindPopup(popup_937fa280095b817c0f9750d584d18d1d)
#         ;

# %%
v_kmeans=silhouette_score(X,class_predictions)
v_kmeans
# Out:
# 0.4158560306726293

# %%
model=DBSCAN(eps=0.1,min_samples=4).fit(X)
class_predictions=model.labels_
df['cluster_DBSCAN']=class_predictions

# %%
m=makemap(df,'cluster_DBSCAN')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66474f830f167d9da0cf6c301cf74bac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66474f830f167d9da0cf6c301cf74bac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66474f830f167d9da0cf6c301cf74bac = L.map(
#                 &quot;map_66474f830f167d9da0cf6c301cf74bac&quot;,
#                 {
#                     center: [17.40384068578199, 78.47765085118483],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82f8f0205d2225dd5cf0e058c92309e0 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_66474f830f167d9da0cf6c301cf74bac);
#
#
#             var circle_marker_261da65a5c34cefd159bd11bc4929fe1 = L.circleMarker(
#                 [17.4212625, 78.430939],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e6194b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e6194b&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_66474f830f167d9da0cf6c301cf74bac);
#
#
#         var popup_6532b13d08dd932f644aadfd1a5a27f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_851f39dd1a2d790db0798e199fadce06 = $(`&lt;div id=&quot;html_851f39dd1a2d790db0798e199fadce06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_6532b13d08dd932f644aadfd1a5a27f0.setContent(html_851f39dd1a2d790db0798e199fadce06);
#
#
#
#         circle_marker_261da65a5c34cefd159bd11bc4929fe1.bindPopup(popup_6532b13d08dd932f644aadfd1a5a27f0)
#         ;
#
#
#
#
#             var circle_marker_1746528473dba3e6011c9f5acd6efa14 = L.circleMarker(
#                 [17.4134005, 78.432999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e6194b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e6194b&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_66474f830f167d9da0cf6c301cf74bac);
#
#
#         var popup_af8a34a4803609397bbf26d9564bd359 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dee6b22e961380a1caeb4c946e74aa02 = $(`&lt;div id=&quot;html_dee6b22e961380a1caeb4c946e74aa02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_af8a34a4803609397bbf26d9564bd359.setContent(html_dee6b22e961380a1caeb4c946e74aa02);
#
#
#
#         circle_marker_1746528473dba3e6011c9f5acd6efa14.bindPopup(popup_af8a34a4803609397bbf26d9564bd359)
#         ;
#
#
#
#
#             var circle_marker_58d71ec8809dc5bac8d3646fee60ae2e = L.circleMarker(
#                 [17.4147109, 78.4398654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e6194b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e6194b&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_66474f830f167d9da0cf6c301cf74bac);
#
#
#         var popup_13b49593b3d3569828d20f16b30682df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d9552f73a047fb7426ae878492ed4cd = $(`&lt;div id=&quot;html_3d9552f73a047fb7426ae878492ed4cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_13b49593b3d3569828d20f16b30682df.setContent(html_3d9552f73a047fb7426ae878492ed4cd);
#
#
#
#         circle_marker_58d71ec8809dc5bac8d3646fee60ae2e.bindPopup(popup_13b49593b3d3569828d20f16b30682df)
#         ;

# %%
vDBSCAN=silhouette_score

# %%
from sklearn.mixture import GaussianMixture 
gmm = GaussianMixture(n_components = 4) 
 
gmm.fit(X) 
   
labels = gmm.predict(X) 
df['cluster_Gaussian']= labels
 
m=makemap(df,'cluster_Gaussian')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12aa2d7ab16762fc4d83ffe424dd3635 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12aa2d7ab16762fc4d83ffe424dd3635&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12aa2d7ab16762fc4d83ffe424dd3635 = L.map(
#                 &quot;map_12aa2d7ab16762fc4d83ffe424dd3635&quot;,
#                 {
#                     center: [17.40384068578199, 78.47765085118483],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfa9b0e5ced0f35d646593f7cb98fb80 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_12aa2d7ab16762fc4d83ffe424dd3635);
#
#
#             var circle_marker_274a0a4423f7e7876498151a8c99bec5 = L.circleMarker(
#                 [17.4212625, 78.430939],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4363d8&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4363d8&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_12aa2d7ab16762fc4d83ffe424dd3635);
#
#
#         var popup_117d8e8126d59f41b60a2538c3306b48 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e376cf8022d4c2bd10d1c83239bafdbf = $(`&lt;div id=&quot;html_e376cf8022d4c2bd10d1c83239bafdbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_117d8e8126d59f41b60a2538c3306b48.setContent(html_e376cf8022d4c2bd10d1c83239bafdbf);
#
#
#
#         circle_marker_274a0a4423f7e7876498151a8c99bec5.bindPopup(popup_117d8e8126d59f41b60a2538c3306b48)
#         ;
#
#
#
#
#             var circle_marker_ce01436860fc7aca5606fd8ae3205bfe = L.circleMarker(
#                 [17.4134005, 78.432999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4363d8&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4363d8&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_12aa2d7ab16762fc4d83ffe424dd3635);
#
#
#         var popup_84fd75f9df2c8f9551d204ba1b44d806 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09f7d3dfc22d9df288fed338c723fa03 = $(`&lt;div id=&quot;html_09f7d3dfc22d9df288fed338c723fa03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_84fd75f9df2c8f9551d204ba1b44d806.setContent(html_09f7d3dfc22d9df288fed338c723fa03);
#
#
#
#         circle_marker_ce01436860fc7aca5606fd8ae3205bfe.bindPopup(popup_84fd75f9df2c8f9551d204ba1b44d806)
#         ;
#
#
#
#
#             var circle_marker_0dd791954477592d5141755d08f2cc58 = L.circleMarker(
#                 [17.4147109, 78.4398654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4363d8&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4363d8&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_12aa2d7ab16762fc4d83ffe424dd3635);
#
#
#         var popup_0aa779188624c2283faf0d1360bc9bb2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79310305e8258f7519042fdbe8aa1db7 = $(`&lt;div id=&quot;html_79310305e8258f7519042fdbe8aa1db7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eve Teasing&lt;/div&gt;`)[0];
#                 popup_0aa779188624c2283faf0d1360bc9bb2.setContent(html_79310305e8258f7519042fdbe8aa1db7);
#
#
#
#         circle_marker_0dd791954477592d5141755d08f2cc58.bindPopup(popup_0aa779188624c2283faf0d1360bc9bb2)
#         ;

# %%
v_Gaussian_Mixture=silhouette_score(X,labels)
v_Gaussian_Mixture
# Out:
# 0.3414367880125702

# %%
plotnames=['kmeans','Gaussian Mixture']

# %%
plotbar=[]
plotbar.append(v_kmeans)

#plotbar.append(vDBSCAN)

plotbar.append(v_Gaussian_Mixture)

# %%
plotbar
# Out:
# [0.4158560306726293, 0.3414367880125702]

# %%
import numpy as np 
import matplotlib.pyplot as plt   
   
fig = plt.figure(figsize = (10, 5)) 
  
# creating the bar plot 
plt.bar(plotnames, plotbar, color ='Blue', width = 0.4) 
plt.xlabel("Algorithms") 
plt.ylabel("silhouette value") 
plt.title("Clustering Efficiency") 
plt.show()

# %%
PlotBarGraphR(['SVM','DecisionTreeClassifier','GaussianNB'],Accuracy_Supervised_Approach,str('Algorithms'),str('Accuracy'),str('Accuracy Report'))
